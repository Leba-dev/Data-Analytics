# %% [markdown]
# Sprint 8.1
#
# Realiza la conexión en Python con MySQL Workbench para cargar toda la información que tienes en las tablas.
#
# Realizarás una visualización para cada ejercicio. Comenta lo que llama la atención de graficar esta variable, justifica la elección del gráfico e interpreta los resultados en función de tus datos.

# %%
#Instalacíon conector python
# %pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Conectar con mysql workbench
import mysql.connector as sql                                  

mydb= sql.connect(
    host= "localhost",
    user="root",
    password="1234",
    database="economy"
    )
print(mydb)

# %%
# Importar data frames 
companies = pd.read_sql("SELECT * FROM companies", mydb)
credit_cards = pd.read_sql("SELECT * FROM credit_cards", mydb)
products = pd.read_sql("SELECT * FROM products", mydb)
trans_products = pd.read_sql("SELECT * FROM trans_products", mydb)
transactions = pd.read_sql("SELECT * FROM transactions", mydb)
users = pd.read_sql("SELECT * FROM users", mydb)
# Out:
# C:\Users\Leba\AppData\Local\Temp\ipykernel_12104\1200256940.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   companies = pd.read_sql("SELECT * FROM companies", mydb)
# C:\Users\Leba\AppData\Local\Temp\ipykernel_12104\1200256940.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   credit_cards = pd.read_sql("SELECT * FROM credit_cards", mydb)
# C:\Users\Leba\AppData\Local\Temp\ipykernel_12104\1200256940.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   products = pd.read_sql("SELECT * FROM products", mydb)
# ...

# %% [markdown]
# Vista de data frames

# %%
print(companies.info())
companies.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_id    100 non-null    object
#  1   company_name  100 non-null    object
#  2   phone         100 non-null    object
#  3   email         100 non-null    object
#  4   country       100 non-null    object
#  5   website       100 non-null    object
# dtypes: object(6)
# memory usage: 4.8+ KB
# None
#   company_id                  company_name           phone  \
# 0     b-2222     Ac Fermentum Incorporated  06 85 56 52 33
# 1     b-2226      Magna A Neque Industries  04 14 44 64 62
# 2     b-2230                   Fusce Corp.  08 14 97 58 85
# 3     b-2234     Convallis In Incorporated  06 66 57 29 50
# 4     b-2238   Ante Iaculis Nec Foundation  08 23 04 99 53
# 5     b-2242                     Donec Ltd  01 25 51 37 37
# ...

# %%
print(credit_cards.info())
credit_cards.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             275 non-null    object
#  1   user_id        275 non-null    object
#  2   iban           275 non-null    object
#  3   pan            275 non-null    object
#  4   pin            275 non-null    object
#  5   cvv            275 non-null    object
#  6   track1         275 non-null    object
#  7   track2         275 non-null    object
#  8   expiring_date  275 non-null    object
# dtypes: object(9)
# memory usage: 19.5+ KB
# None
#          id user_id                          iban                  pan   pin  \
# 0  CcU-2938     275    TR301950312213576817638661     5424465566813633  3257
# 1  CcU-2945     274  DO26854763748537475216568689     5142423821948828  9080
# 2  CcU-2952     273        BG45IVQL52710525608255     4556 453 55 5287  4598
# ...

# %%
print(products.info())
products.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            100 non-null    object
#  1   product_name  100 non-null    object
#  2   price         100 non-null    object
#  3   colour        100 non-null    object
#  4   weight        100 non-null    object
#  5   warehouse_id  100 non-null    object
# dtypes: object(6)
# memory usage: 4.8+ KB
# None
#     id         product_name    price   colour weight warehouse_id
# 0    1     Direwolf Stannis  $161.11  #7c7c7c      1         WH-4
# 1   10       Karstark Dorne  $119.52  #f4f4f4    2.4        WH--5
# 2  100           south duel   $40.43  #6d6d6d      3       WH--95
# 3   11       Karstark Dorne   $49.70  #141414    2.7        WH--6
# 4   12        duel Direwolf  $181.60  #a8a8a8    2.1        WH--7
# 5   13  palpatine chewbacca  $139.59  #2b2b2b      1        WH--8
# ...

# %%
print(trans_products.info())
trans_products.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_transaction  1236 non-null   object
#  1   id_product      1236 non-null   object
# dtypes: object(2)
# memory usage: 19.4+ KB
# None
#                          id_transaction id_product
# 0  02C6201E-D90A-1859-B4EE-88D2986D3B02          1
# 1  122DC333-E19F-D629-DCD8-9C54CF1EBB9A          1
# 2  1753A288-9FC1-52E6-5C39-A1FFB97B0D3A          1
# 3  1A6CECFB-2E3A-65A3-72D9-2FDB58A1E4BA          1
# 4  1EA2B262-D507-AD14-4374-4D532967113F          1
# 5  23CF8ED3-402C-7C54-59CD-DB505C5CCCCE          1
# 6  2A5A3001-104F-1D1F-7852-5BA801869B6F          1
# 7  2F3B6AB6-147D-EB0B-FE8D-9A4E2EA9DBD5          1
# 8  2F499B4D-4DC7-B337-010D-8B7471812A80          1
# 9  2F74E99B-9337-7F74-5208-5DEC81A174FD          1

# %%
print(transactions.info())
transactions.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           587 non-null    object
#  1   card_id      587 non-null    object
#  2   business_id  587 non-null    object
#  3   timestamp    587 non-null    object
#  4   amount       587 non-null    object
#  5   declined     587 non-null    object
#  6   product_ids  587 non-null    object
#  7   user_id      587 non-null    object
#  8   lat          587 non-null    object
#  9   longitude    587 non-null    object
# dtypes: object(10)
# memory usage: 46.0+ KB
# None
#                                      id   card_id business_id  \
# 0  02C6201E-D90A-1859-B4EE-88D2986D3B02  CcU-2938      b-2362
# 1  0466A42E-47CF-8D24-FD01-C0B689713128  CcU-4219      b-2302
# 2  063FBA79-99EC-66FB-29F7-25726D1764A5  CcU-2987      b-2250
# ...

# %%
transactions["amount"] = transactions["amount"].astype(float)
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           587 non-null    object
#  1   card_id      587 non-null    object
#  2   business_id  587 non-null    object
#  3   timestamp    587 non-null    object
#  4   amount       587 non-null    float64
#  5   declined     587 non-null    object
#  6   product_ids  587 non-null    object
#  7   user_id      587 non-null    object
#  8   lat          587 non-null    object
#  9   longitude    587 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 46.0+ KB

# %%
print(users.info())
users.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          275 non-null    object
#  1   name        275 non-null    object
#  2   surname     275 non-null    object
#  3   phone       275 non-null    object
#  4   email       275 non-null    object
#  5   birth_date  275 non-null    object
#  6   country     275 non-null    object
#  7   city        275 non-null    object
#  8   post_code   275 non-null    object
#  9   address     275 non-null    object
# dtypes: object(10)
# memory usage: 21.6+ KB
# None
#     id     name     surname           phone                          email  \
# 0    1     Zeus      Gamble  1-282-581-0551   interdum.enim@protonmail.edu
# 1   10   Robert    Mccarthy  (324) 746-6771       fermentum@protonmail.com
# 2  100  Melodie      Mclean  1-677-221-7152         risus.varius@google.ca
# ...

# %%
#Ex1 Una variable numérica.


sns.histplot(data=transactions, x="amount", kde=True) 
plt.title("Frecuencia de las transacciones")
plt.show();

# %% [markdown]
# Interpretación del gráfico
#
# La mayoría de las compras son de bajo valor.
# La mayor cantidad de transacciones se concentra en montos inferiores a 100.
# A medida que el monto aumenta, la cantidad de transacciones disminuye: Hay menos personas que realizan compras grandes.
# Existe un pico en compras de un monto específico: Entre 400 y 450, hay un aumento en el número de transacciones, lo que sugiere que existe un producto o servicio popular en ese rango de precios.
#
# En resumen:
# La tendencia general es que las personas prefieren realizar transacciones de bajo valor, aunque existen algunos casos de compras más grandes, especialmente en un rango de precios específico.

# %%
#Ex2 Dos variables numéricas.

#Modificacion formato de campos
products["price"] = products["price"].str.replace("$", "")
products["price"] = products["price"].astype("float")

# %%
products["weight"] = products["weight"].astype("float")
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            100 non-null    object
#  1   product_name  100 non-null    object
#  2   price         100 non-null    float64
#  3   colour        100 non-null    object
#  4   weight        100 non-null    float64
#  5   warehouse_id  100 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 4.8+ KB

# %%
sns.scatterplot(data=products,
            x='price',
            y='weight')
plt.xlabel('Precio', fontsize=12)
plt.ylabel('Peso', fontsize=12)
plt.title("Relación precio/peso");

# %% [markdown]
# Interpretación del gráfico
#
# No hay una relación clara entre el peso y el precio: Los puntos en el gráfico están dispersos sin formar una línea o curva definida, lo que indica que al aumentar el peso, no necesariamente aumenta o disminuye el precio.
# Existe un rango de peso sin productos: Llama la atención que no hay productos con un peso entre 1.5 y 2.0 kilogramos, independientemente de su precio. Esto sugiere que podría haber algún factor o restricción que impida que se ofrezcan productos en ese rango de peso.
#
# En resumen
# Este gráfico nos muestra que el precio de un producto no depende necesariamente de su peso, y que existe una brecha en la oferta de productos con un peso específico.

# %%
#Ex3 Una variable categórica.
sns.countplot(data=companies, x='country') 
plt.title("Conteo de empresas por país")
plt.xticks(rotation=80) #rotamos las etiquetas del eje X 80 grados para facilitar la lectura porque sino se amontonan.
plt.tight_layout() #prevenimos que las etiquetas o el título se solapen y se vea ordenado.
plt.xlabel('País', fontsize=12)
plt.ylabel('Recuento empresas', fontsize=12)
plt.show()

# %% [markdown]
# Interpretación del gráfico
#
# Principales hallazgos:
#
# Alta concentración en algunos países: Suecia y los Países Bajos lideran el conteo de empresas, mientras que España y China presentan los números más bajos.
# Grupo intermedio: Un grupo de países, incluyendo Canadá, Noruega y algunos de Oceanía, muestra un nivel de participación empresarial intermedio.
# Grupo con mayor similitud: Italia, Reino Unido y Estados Unidos presentan un perfil empresarial similar con un número cercano de empresas.
#
# Recomendaciones:
#
# Desequilibrios en la distribución: La desigualdad en la presencia empresarial plantea desafíos para una distribución global más equitativa.
# Necesidad de estrategias diferenciadas: Es crucial implementar estrategias específicas para cada país, enfocadas en:
# Países con bajo rendimiento: Identificar barreras de entrada y desarrollar programas de incentivos para atraer más empresas.
# Países con alto rendimiento: Preservar y optimizar las prácticas exitosas.
#
# Análisis de mercado:
# Realizar un análisis profundo de los mercados español y chino para comprender las razones detrás de su menor participación empresarial.
# Inversión en marketing: Aumentar las inversiones en campañas de marketing dirigidas a estos países para generar mayor interés y atraer nuevas empresas.
#
# En resumen:
# El análisis del gráfico de barras pone de manifiesto la necesidad de adoptar un enfoque estratégico y personalizado para cada país.
# Con el objetivo de lograr una distribución más equilibrada y sostenible de las transacciones a nivel global.

# %%
# Ex4 Una variable categórica y una numérica.
#realizamos un método merge ,es como un join en mysql para relacionar tablas entre sí.
df_combi = pd.merge(companies, transactions, left_on='company_id', right_on='business_id') 
plt.figure(figsize=(12, 6))                                                                   
sns.boxplot(x='country', y='amount', data=df_combi)                                       
plt.title('Transacciones por país', fontsize=16)                                   
plt.xlabel('País', fontsize=12)
plt.ylabel('Transacción (€)', fontsize=12)
plt.xticks(rotation=45)                                                                        
plt.tight_layout()                                                                             
plt.show();

# %% [markdown]
# Interpretación del gráfico
#
# El gráfico muestra grandes diferencias en los montos de las transacciones entre países.
#
# Países del norte vs. sur:
# Los países del norte de Europa (como Estados Unidos, Reino Unido y Países Bajos) tienen, en promedio, transacciones mucho más altas que los países del sur (España, Francia e Italia).
#
# Variabilidad:
# Algunos países, como España, Francia y China, muestran menos variación en los montos de sus transacciones, mientras que otros tienen una mayor dispersión.
#
# Valor atípico:
# Francia presenta una transacción excepcionalmente alta, lo que rompe con la tendencia general de este país.
#
# Posibles explicaciones:
# Las diferencias en los montos de las transacciones podrían deberse a factores culturales, geográficos, económicos y políticos.
#
# Recomendaciones:
# Políticas para estimular el consumo: Los países con menores transacciones (como España) podrían implementar políticas para aumentar el consumo, como estudios de mercado, identificación de productos demandados y programas de incentivos.
# Mantenimiento del consumo: Los países con altas transacciones (como Estados Unidos) deberían enfocarse en estrategias para mantener el nivel de consumo actual, como bonificaciones o programas de fidelización.
#
# En resumen:
# El gráfico revela una marcada desigualdad en los hábitos de consumo entre diferentes países. Para abordar esta situación, se proponen acciones específicas para estimular el consumo en unos casos y mantenerlo en otros.Las medianas no siguen una tendencia clara en todos los paises, si que es cierto que en europa se ve una tendencia al alza. Algun pais tiene algun dato anomalos ej Francia.

# %%
#Ex5 Dos variables categóricas.

# Convertir 'declined' en categórica
df_combi['declined'] = df_combi['declined'].astype(int)  # Asegúrate de que sea un entero
df_combi['estado_transaccion'] = df_combi['declined'].map({0: 'Aprobada', 1: 'Rechazada'}).astype('category')

# %%
#5
transactions["declined"] = transactions["declined"].astype("int")

transactions_companies = pd.merge(transactions, companies, left_on='business_id', right_on='company_id')

sns.catplot(data=transactions_companies[transactions_companies['declined'] == 1],
            y='country',
            kind='count');

# %% [markdown]
# Interpretación del gráfico
#
# Suecia lidera las tasas de rechazo:
# Con un 12.6%, Suecia presenta la tasa más alta, lo que sugiere problemas en sus sistemas de pago o políticas de verificación.
#
# Otros países con altas tasas:
# Países Bajos, Italia y Estados Unidos también tienen tasas de rechazo significativas, alrededor del 9.2%.
#
# Tendencias intermedias:
# Irlanda y Alemania presentan tasas de rechazo del 6.9%, mientras que Bélgica y Canadá tienen tasas del 5.7% y 4.6%, respectivamente.
#
# Países con bajas tasas:
# España y China muestran las tasas más bajas, pero su bajo volumen de transacciones limita la significancia de estos datos.
#
# Recomendaciones:
#
# Investigación de causas:
# Es necesario investigar a fondo las razones detrás de las altas tasas de rechazo en países como Suecia, Países Bajos, Italia y Estados Unidos.
#
# Optimización de sistemas:
# Se deben optimizar los métodos de pago y las políticas de validación para reducir las tasas de rechazo.
#
# Atención a países con tendencias intermedias:
# Irlanda y Alemania requieren atención para prevenir un aumento en las tasas de rechazo.
#
# Crecimiento equilibrado:
# España y China deben abordar aspectos que les permitan lograr un crecimiento empresarial más equilibrado y aumentar su volumen de transacciones.
#
# En resumen:
# El gráfico revela una necesidad de mejorar los sistemas de pago y las políticas de verificación en varios países, especialmente en aquellos con las tasas de rechazo más altas. Además, se destaca la importancia de analizar las razones detrás de estas tasas para implementar soluciones efectivas.

# %%
# Ex6 Tres variables.
plt.xticks(rotation=85)
plt.tight_layout()
sns.barplot(data=df_combi,
            x='country',
            y='amount',
            hue='declined')
plt.xlabel('País', fontsize=12)
plt.ylabel('Promedio Transacciones', fontsize=12);

# %% [markdown]
# Interpretación del gráfico
#
# El gráfico muestra que en muchos países se rechazan más transacciones de las que se aprueban.
#
# Desequilibrio general:
# Nueve de los 15 países analizados presentan una mayor cantidad de transacciones rechazadas en comparación con las aprobadas.
#
# Países con mayor discrepancia:
# Canadá, EE. UU., Nueva Zelanda y Australia son los que muestran la mayor diferencia entre transacciones aprobadas y rechazadas.
#
# España como caso particular:
# España presenta el menor volumen total de transacciones, tanto aprobadas como rechazadas.
#
# Causas posibles:
# Las políticas de validación, los métodos de pago y otros factores internos podrían estar influyendo en las altas tasas de rechazo.
#
# Recomendaciones:
#
# Análisis detallado:
# Las empresas deben investigar a fondo las razones detrás de los altos índices de rechazo en cada país.
#
# Revisión de políticas:
# Es necesario revisar las políticas de validación y los métodos de pago aceptados para identificar áreas de mejora.
#
# Auditorías y encuestas:
# Realizar auditorías del sistema de pagos y encuestas a los clientes puede proporcionar información valiosa para optimizar los procesos.
#
# En resumen:
# El gráfico revela un problema generalizado de altas tasas de rechazo de transacciones en varios países. Para solucionarlo, es necesario que las empresas realicen un análisis profundo y tomen medidas para mejorar sus procesos y políticas.

# %%
#ex7 Graficar un Pairplot.
products["weight"] = products["weight"].astype("float")
sns.pairplot(data=products)
plt.show();

# %% [markdown]
# Interpretación del gráfico
#
# Los gráficos muestran una relación entre el precio y el peso de los productos.
#
# Falta de correlación directa:
# El peso de los productos no parece estar directamente relacionado con su precio. Los puntos en el gráfico de dispersión están dispersos sin seguir un patrón claro.
#
# Distribución de precios :
# Los precios de los productos se concentran en dos rangos principales: uno bajo y otro alto. La mayoría de los productos se encuentran en estos dos extremos.
#
# Distribución de peso más normal:
# El peso de los productos, por otro lado, tiene una distribución más uniforme, concentrándose en un rango medio entre 1.5 y 2.5 kilogramos.
#
# Otros factores:
# La determinación del precio de los productos parece estar más influenciada por factores como la calidad, la marca o la funcionalidad, más que por el peso.
#
# En resumen:
# Los gráficos indican que el peso no es el principal factor que determina el precio de un producto. Otros elementos, como la calidad y la marca, parecen jugar un papel más importante en la fijación de precios.
